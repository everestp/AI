# %%
## hello

# %%
print(1)
# Out:
# 1

# %%
name ="everest"
Name ="everest1"
print(name)
print(Name)
# Out:
# everest
# everest1

# %%
age=32
if age > 30:
    print("The age is ",age)
print(age)
# Out:
# The age is  32
# 32

# %%
##Line Contination
total=1+2+3+4+5+6+7 +\
4
print(total)
# Out:
# 32

# %%
##Understand Semantic In Python
age=32
bame="everest"
type(age)
# Out:
# int

# %%
#create a todo list

to_do_list = ["Buy Groceries","Clean the house"]

to_do_list.append("Learn AI")

#Removinh a completed tasj
to_do_list.remove("Buy Groceries")

## checking if as task is in the list
if "Clean the house":
  print("Hey to You forgot ti clean the house")
  print("To do list reming")
  for task in  to_do_list:
    print(task)
# Out:
# Hey to You forgot ti clean the house
# To do list reming
# Clean the house
# Learn AI

# %%
 #set in pythobn
my_set  = {1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
##Set
#hello
my_set = {1,3}
